# %%
from nomenklatura import Dataset

dataset = Dataset('ds_nd',host='http://nomenklatura.okfnlabs.org/', api_key='eb05ea99-3198-4392-ab5a-b22fb39b730b')

in_value = dataset.ensure_value('This is a reference value')

try:
    key = 'This needs to be reconciled'
    out_value = dataset.lookup(key, readonly=False)
    print(out_value.value)
except:
    print('exception occurred')
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-e9a65a3d529a> in <module>()
#       1 from nomenklatura import Dataset
#       2
# ----> 3 dataset = Dataset('ds_nd',host='http://nomenklatura.okfnlabs.org/', api_key='eb05ea99-3198-4392-ab5a-b22fb39b730b')
#       4
#       5 in_value = dataset.ensure_value('This is a reference value')
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __init__(self, dataset, host, api_key)
#      93       self.name = dataset
#      94       self.api_key = api_key
# ---> 95       self._fetch()
#      96
#      97   @property
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in _fetch(self)
#     126
#     127   def _fetch(self):
# --> 128       code, data = self._get('')
#     129       if not (code == 200 and data):
#     130           data = data or {'code': code}
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in _get(self, path, params, retry)
#     107
#     108   def _get(self, path, params={}, retry=True):
# --> 109       response = self._session.get(self.host + '/' + self.name + path,
#     110                                    params=params)
#     111       if not response.ok:
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in _session(self)
#      97   @property
#      98   def _session(self):
# ---> 99       if not hasattr(self, '_session_obj'):
#     100           headers = {'Accept': 'application/json',
#     101                      'Content-Type': 'application/json'}
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# ...
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# /usr/local/lib/python3.6/site-packages/nomenklatura.py in __getattr__(self, k)
#      10
#      11   def __getattr__(self, k):
# ---> 12       return self.__data__[k]
#      13
#      14   def __str__(self):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
